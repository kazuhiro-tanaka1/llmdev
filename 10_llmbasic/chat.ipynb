# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"
# Out:
# {'_request_id': 'req_2a2a4378a8a54479b1e1e3eb3e758554',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使う上でのポイントはいくつかあります。以下に挙げるのは、効果的に利用するための主なポイントです。\n\n1. **目的を明確にする**: 言語モデルを使用する目的を明確にすることが重要です。情報検索、文章生成、質問応答、要約など、用途によって求められる出力が異なります。\n\n2. **プロンプトの設計**: モデルに与える入力（プロンプト）の設計が結果に大きく影響します。具体的で明確な指示を与えることで、期待する応答を得やすくなります。\n\n3. **文脈の提供**: モデルに必要な背景情報や文脈を提供することで、より適切な応答を引き出すことが可能です。\n\n4. **フィードバックの活用**: モデルからの応答を評価し、不満足な場合はプロンプトを修正するなどして、改善を図ることが重要です。\n\n5. **懸念点への配慮**: モデルが生成する情報に正確性や誤情報を含む可能性があるため、結果をそのまま鵜呑みにせず、一定の批判的視点を持つことが大切です。\n\n6. **倫理的配慮**: 言語モデルを使用する際には、倫理的な側面にも配慮が必要です。特に、差別的な表現や誤情報の拡散を避けるための注意が求められます。\n\n7. **適切なツールの選定**: 使用する言語モデルやプラットフォームの特性を理解し、用途に応じて適切なツールを選ぶことも重要です。\n\n8. **継続的な学習**: 言語モデルやその応用は急速に進化しているため、最新の技術やトレンドについて学び続けることが重要です。\n\nこれらのポイントを考慮しながら言語モデルを活用することで、より良い結果を得ることができるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1776424065,
#  'id': 'chatcmpl-DVbKzJvXY6eqKvf8AwhdK9uNNH4oG',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_83e2dd34fc',
#  'usage': CompletionUsage(completion_tokens=500, prompt_tokens=18, total_tokens=518, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}
# 言語モデルを使う上でのポイントはいくつかあります。以下に挙げるのは、効果的に利用するための主なポイントです。
#
# 1. **目的を明確にする**: 言語モデルを使用する目的を明確にすることが重要です。情報検索、文章生成、質問応答、要約など、用途によって求められる出力が異なります。
#
# 2. **プロンプトの設計**: モデルに与える入力（プロンプト）の設計が結果に大きく影響します。具体的で明確な指示を与えることで、期待する応答を得やすくなります。
#
# 3. **文脈の提供**: モデルに必要な背景情報や文脈を提供することで、より適切な応答を引き出すことが可能です。
#
# 4. **フィードバックの活用**: モデルからの応答を評価し、不満足な場合はプロンプトを修正するなどして、改善を図ることが重要です。
#
# 5. **懸念点への配慮**: モデルが生成する情報に正確性や誤情報を含む可能性があるため、結果をそのまま鵜呑みにせず、一定の批判的視点を持つことが大切です。
#
# 6. **倫理的配慮**: 言語モデルを使用する際には、倫理的な側面にも配慮が必要です。特に、差別的な表現や誤情報の拡散を避けるための注意が求められます。
#
# 7. **適切なツールの選定**: 使用する言語モデルやプラットフォームの特性を理解し、用途に応じて適切なツールを選ぶことも重要です。
#
# 8. **継続的な学習**: 言語モデルやその応用は急速に進化しているため、最新の技術やトレンドについて学び続けることが重要です。
#
# これらのポイントを考慮しながら言語モデルを活用することで、より良い結果を得ることができるでしょう。

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_872156e7fc6f42d5b302a2f98a499b02',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に活用するためのポイントはいくつかあります。以下に重要な点を挙げます。\n\n1. **明確な目的を持つ**: 言語モデルを使う目的を明確にし、具体的な質問やタスクを設定することで、より良い結果が得られます。\n\n2. **入力の工夫**: 質問や要求を具体的に、かつ明確に表現することが重要です。曖昧な表現は期待通りの結果を得られにくくなります。\n\n3. **コンテキストの提供**: 必要に応じて、関連情報や背景を提供することで、モデルがその情報を考慮に入れて応答することができます。\n\n4. **フィードバックの活用**: 結果に対してフィードバックを与えることで、次回の応答を改善する手助けになります。具体的な指摘や追加の情報を与えることで、より洗練された回答が得られます。\n\n5. **専門知識の検証**: 特に専門的な内容に関しては、モデルの応答を鵜呑みにせず、信頼できる情報源で確認することが重要です。\n\n6. **プライバシーへの配慮**: 個人情報や機密情報を入力しないようにし、プライバシーを守ることが大切です。\n\n7. **限界の理解**: 言語モデルには限界があるため、理解力や推論能力において人間には及ばない場合が多いことを認識しておくことが重要です。\n\nこれらのポイントを意識することで、言語モデルをより効果的に活用できるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1776424164,
#  'id': 'chatcmpl-DVbMaMfgVaDAj8aOHl0yLQxDnlrmn',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_83e2dd34fc',
#  'usage': CompletionUsage(completion_tokens=411, prompt_tokens=18, total_tokens=429, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを効果的に活用するためのポイントはいくつかあります。以下に重要な点を挙げます。
#
# 1. **明確な目的を持つ**: 言語モデルを使う目的を明確にし、具体的な質問やタスクを設定することで、より良い結果が得られます。
#
# 2. **入力の工夫**: 質問や要求を具体的に、かつ明確に表現することが重要です。曖昧な表現は期待通りの結果を得られにくくなります。
#
# 3. **コンテキストの提供**: 必要に応じて、関連情報や背景を提供することで、モデルがその情報を考慮に入れて応答することができます。
#
# 4. **フィードバックの活用**: 結果に対してフィードバックを与えることで、次回の応答を改善する手助けになります。具体的な指摘や追加の情報を与えることで、より洗練された回答が得られます。
#
# 5. **専門知識の検証**: 特に専門的な内容に関しては、モデルの応答を鵜呑みにせず、信頼できる情報源で確認することが重要です。
#
# 6. **プライバシーへの配慮**: 個人情報や機密情報を入力しないようにし、プライバシーを守ることが大切です。
#
# 7. **限界の理解**: 言語モデルには限界があるため、理解力や推論能力において人間には及ばない場合が多いことを認識しておくことが重要です。
#
# これらのポイントを意識することで、言語モデルをより効果的に活用できるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略は、以下のステップに従って構築することが重要です。
#
# ### 1. 市場調査の実施
# - **ターゲットオーディエンスの特定**: 新製品の主要な顧客層を明確にし、そのニーズや嗜好を理解します。
# - **競合分析**: 同業他社の製品、価格設定、マーケティング戦略を調査し、差別化のポイントを見つけます。
#
# ### 2. 製品ポジショニング
# - **USPの明確化**: 新製品のユニークなセールスポイント（Unique Selling Proposition）を特定し、それをマーケティングメッセージに反映させます。
# - **ブランドストーリーの構築**: 製品にまつわるストーリーやビジョンを伝え、消費者との感情的なつながりを築きます。
#
# ### 3. マルチチャネルマーケティング
# - **デジタルマーケティングを活用**: ソーシャルメディア、メールマーケティング、SEO、PPC広告等を利用して、オンラインプレゼンスを強化します。
# - **プレスリリースとメディアエンゲージメント**: 新製品の発表に関するプレスリリースを作成し、業界メディアと提携して広報活動を行います。
#
# ### 4. プロモーション戦略
# - **ティーザーキャンペーン**: 製品の発売前に興味を引くコンテンツや広告を展開し、期待感を高めます。
# - **インフルエンサーとのコラボレーション**: 関連するインフルエンサーに製品を紹介してもらい、信頼性を高めます。
# - **プロモーションイベントやウェビナーの開催**: 新製品を紹介するためのオフラインまたはオンラインイベントを計画し、参加者とのインタラクションを促します。
#
# ### 5. フィードバックとデータ分析
# - **初期フィードバックの収集**: アンケートやレビューを通じて、顧客の反応を観察し、改善点を見つけることが重要です。
# - **パフォーマンスのトラッキング**: KPI（重要業績評価指標）を設定し、キャンペーンや販売データを分析し、必要に応じて戦略を調整します。
#
# ### 6. アフターフォロー
# - **顧客サポートの強化**: 購入後のサポートやアフターケアを提供し、顧客満足度を向上させ、リピート購入を促します。
# - **コミュニティの構築**: 新製品のファンコミュニティを構築して、顧客同士の交流を促進し、ブランドロイヤリティを強化します。
#
# これらのステップをしっかりと実行することで、新製品の市場での成功を高めることができます。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な特徴がある魅力的な国です。ここにいくつかのポイントを挙げてみます：
#
# 1. **文化と伝統**: 日本は独自の文化と伝統が息づく国です。茶道、花道（生け花）、書道、武道など、伝統芸能や習慣が根付いています。年中行事や祭りも豊富
# --------------------
# もちろん、日本には多くの魅力があります！いくつか紹介しますね。
#
# 1. **美しい自然**: 日本は四季が豊かで、春の桜、夏の海、秋の紅葉、冬の雪景色を楽しむことができます。特に、富士山や山岳信仰で知られる山々など、絶景が広がっています。
#
# 2. **文化と歴史**: 日本の伝統
# --------------------
# 日本の魅力は多岐にわたりますが、以下のポイントをいくつかご紹介します。
#
# ### 1. 文化・伝統
# - **歴史的な建造物**: 京都の寺院や大阪城、奈良の古寺など、日本各地には歴史的な建物が多数存在します。
# - **祭り・行事**: 桜の季節には多くのお花見や、夏祭

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを挙げてみます。
#
# 1. **歴史と文化**: 日本には古い歴史と独自の文化があります。京都の神社や寺、伝統的な茶道や華道、武道など、歴史的な文化が今も大切にされています。
#
# 2. **美しい自然**: 日本の自然風景は多様です
# --------------------
# 日本はその独自の文化、歴史、自然の美しさ、そして先進的な技術で知られています。以下に日本の魅力をいくつか紹介します。
#
# 1. **文化と伝統**: 日本は伝統的な文化と現代文化が共存しています。茶道、華道、書道、そして神道や仏教に基づく祭りなど、さまざまな伝統が
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# 日本は、長い歴史と豊かな文化を持っています。伝統的な祭りや茶道、和歌、和服、相撲など、さまざまな文化的要素が今も受け継がれています。
#
# ### 2. 食文化
# 日本の食は

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん！元気ですか？
# --------------------
# B:こんにちは、Aさん！最近はどうしてる？
# --------------------
# B:こんにちは！どうしていたの？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主なものを挙げます。
#
# 1. **目的に応じたモデルの選択**: 利用するタスクや目的に応じて、適切な言語モデルを選ぶことが重要です。例えば、テキスト生成、要約、翻訳、感情分析など、用途によって最適なモデルが異なります。
#
# 2. **プロンプトの工夫**: モデルに与える入力（プロンプト）を工夫することで、得られる出力の品質が大きく変わります。明確で具体的な指示を与えると良い結果が得られやすいです。
#
# 3. **コンテキストの提供**: モデルはコンテキストを考慮します。必要な情報や背景を与えることで、より関連性の高い応答が得られます。
#
# 4. **フィルタリングとモデレーション**: 自動生成されたテキストは必ずしも正確であったり、望ましい内容とは限りません。生成物をレビューし、必要に応じて調整やフィルタリングを行うことが重要です。
#
# 5. **倫理的な配慮**: 言語モデルはバイアスを含む可能性があります。出力された情報が倫理的に適切であることを確認し、不適切な内容が生成されないように注意する必要があります。
#
# 6. **ユーザーとの対話**: 特に対話形式で使用する場合、ユーザーからのフィードバックを受け取り、応答を調整することで、より良い体験を提供できます。
#
# 7. **限界の理解**: 言語モデルには限界があります。知識は学校教育のデータやインターネット上の情報に基づいているため、最新の情報や特定の専門的な知識については不完全な場合があります。
#
# 8. **繰り返し試行と調整**: 一度の試行で完璧な結果が得られるとは限りません。異なるアプローチやパラメータを試すことで、望ましい結果に近づける可能性があります。
#
# これらのポイントを意識しながら言語モデルを活用することで、より効果的かつ有益な結果が得られるでしょう。
